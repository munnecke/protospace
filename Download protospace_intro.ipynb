# %% [markdown]
# # Protospace: A Colab-Based Investigation
#
# This notebook explores the hypothesis that space may exist in multiple phases—entropic and autocatalytic—and that cosmic voids may mark transitions between them.
#
# We'll begin by:
# - Loading Planck CMB temperature and polarization maps
# - Loading an SDSS/ZOBOV void catalog
# - Extracting sky patches near void edges
# - Computing entropy or compressibility metrics
#
# This is a first test of whether structure or coherence exists at the edge of known cosmic voids.

# %%
# Install essential packages
# !pip install healpy astroquery astropy matplotlib numpy
import healpy as hp
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %% [markdown]
# ## Next Steps:
# We will load the Planck polarization map (IQU) and retrieve a known void catalog to begin analyzing localized regions.
